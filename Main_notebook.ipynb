# %%
import sys
from itertools import chain

#!pip install -r requirements.txt

# common tools
import pickle
import pandas as pd
import collections
from collections import Counter
from tqdm import tnrange, tqdm_notebook

# from io import StringIO
import numpy as np

# nlp tools
from string import punctuation
import pymystem3
import pymorphy2
import nltk
import gensim
from gensim.models import KeyedVectors
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# own libs
# !pip install dill
import preprocessing_methods as pm

# plottin'
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from pylab import rcParams
# Setting figure size in inches
rcParams['figure.figsize'] = 16, 7
pal = sns.palplot(sns.color_palette("RdBu_r", 6))

# %%
train_path = 'X_train.csv'
df = pd.read_csv(train_path)# , delimiter=',', error_bad_lines=False, header=None)
df.head(2)
# Out:
#         sku  categoryLevel1Id  categoryLevel2Id  brandId  \
# 0  20005023               401           4010201      826
# 1  20020647               403           4030101     1425
#
#                                             property  \
# 0  [{34: 'f982777489055c6563d68c005fd24aad'}, {36...
# 1  [{34: '9ce895413ebdf6b6dcb69b07dc782591'}, {36...
#
#                            userName  reting        date  \
# 0  b2898a81b45310b30beb8fc0c0a9ce1e     2.0  2013-06-28
# 1  538c73d64461e13907bb95c51c38bfbc     2.0  2010-07-04
#
#                                              comment commentNegative  \
# 0  2,5 года работала и все...устала! Лампочка гор...             NaN
# 1  Через 2 месяца после истечении гарантийного ср...             NaN
#
#   commentPositive
# 0             NaN
# 1             NaN

# %%
comment = df['comment'].dropna()
commentPositive = df['commentPositive'].dropna()
commentNegative = df['commentNegative'].dropna()

# %%
dataset = (comment, commentPositive, commentNegative)

# %%
pp = pm.Preprocessing()

# %%
def get_stats(a, b, c):
    # Считаем количество символов
    count_a = len(list(chain.from_iterable(a)))
    count_b = len(list(chain.from_iterable(b)))
    count_c = len(list(chain.from_iterable(c)))
    print('Symbols:', count_a, count_b, count_c)

# %%
def apply_to_dataset(dataset, func):
    pros = dataset[0].apply(func)
    cons = dataset[1].apply(func)
    otziv = dataset[2].apply(func)
    get_stats(pros, cons, otziv)
    return (pros, cons, otziv)

# %%
normalized = apply_to_dataset(dataset, pp.normalize)
padded = apply_to_dataset(normalized, pp.pad_punctuation)
tokenized = apply_to_dataset(padded, nltk.word_tokenize) # counting tokens now
no_punct = apply_to_dataset(tokenized, pp.remove_punct)
no_stopwords = apply_to_dataset(no_punct, pp.remove_stopwords)
# Out:
# Symbols: 4691513 323849 38231
# Symbols: 4907125 336671 39589
# Symbols: 869355 58728 6966
# Symbols: 699364 48205 5837
# Symbols: 506102 34500 4637

# %%
# Most frequent tokens over all columns
# Most frequent tokens over all columns
def get_most_frequent_df(dataset):
    most_common_tokens = Counter(chain.from_iterable(list(chain.from_iterable(dataset)))).most_common()
    df = pd.DataFrame(  {'token': [each[0] for each in most_common_tokens],
                               'occurance':  [each[1] for each in most_common_tokens],
                              }).reset_index()
    df.columns = ['rank', 'occurance', 'token']
    return df

freq_df_1 = get_most_frequent_df(no_stopwords)
freq_df_1.head()
# Out:
#    rank  occurance     token
# 0     0      21912        не
# 1     1       7658     очень
# 2     2       2509       нет
# 3     3       2391    просто
# 4     4       2198  работает

# %%
# Index = frequency rank
ax = sns.lmplot(x='rank', y='occurance', data=freq_df_1.head(100), size=6)

# %%
vocab = list(freq_df_1['token'].values)
print('vocab len: ', len(vocab))
cyrillic_vocab = [each for each in vocab if pm.is_cyrillic(each)]
print('cyrillic left only: ', len(cyrillic_vocab))
# cut_vocab = list(token_occ_df[token_occ_df['occurance']>5]['token'].values)
# print(len(cut_vocab))
# Out:
# vocab len:  65534
# cyrillic left only:  52225

# %%
lemma_dict = {}
for each in tnrange(len(cyrillic_vocab), desc='constructing dict'):
    token = cyrillic_vocab[each]
    lemma_dict.update({token: pp.get_pymorphy_lemma(token)})

# %%
def replace_lemmas(tokenlist):
    result = []
    for token in tokenlist:
        if token in lemma_dict.keys():
            result.append(lemma_dict[token])
        else:
            result.append(token)
    return result

# %%
lemmatized = apply_to_dataset(dataset=no_stopwords, func=replace_lemmas)
freq_df_2 = get_most_frequent_df(lemmatized)
# Out:
# Symbols: 506102 34500 4637

# %%
def cut_by_frequcncy(tokenlist):
    freq_vocab = list(freq_df_2[freq_df_2['occurance']>5]['token'].values)
    return [t for t in tokenlist if t in freq_vocab]
cu_by_freq_dataset = apply_to_dataset(lemmatized, cut_by_frequcncy)
# Out:
# Symbols: 465383 31892 4351

# %%
get_most_frequent_df(cu_by_freq_dataset).head(10)
# Out:
#    index  occurance         token
# 0      0      21912            не
# 1      1       7658         очень
# 2      2       4751        купить
# 3      3       4228       хороший
# 4      4       4157           год
# 5      5       3082      работать
# 6      6       2597  пользоваться
# 7      7       2509           нет
# 8      8       2447      отличный
# 9      9       2391        просто

# %% [markdown]
# # Token category filtering

# %%
full_punctuation = punctuation+'«»'
full_punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~«»'

# %%
# Flat list of all tokens in all texts
def series_to_chain(series):
    """Chained tokens in Series"""
    return series

# %%
def separate_by_category(dataset):
    """ 
    Separates tokens by types of chars in it (punctuation, numbers, ...)
    Takes tokenized texts as input 
    Returns dict of {category:[tokenlist]}
    """
    # all_columns = list(chain(*dataset))
    # print(len(all_columns))
    tokenlists = list(chain(*dataset)) # list(chain.from_iterable(all_columns))
    tokens = list(chain(*tokenlists))
    print(len(tokens))
    
    result = {'num_punct': [],
               'alpha_num': [],
               'alpha_punct': [],
               'punct_tokens': [],
               'numeric_tokens': [],
               'alpha_tokens': [],
               'alpha_num_punct': []}

    for token in tokens:
        # Add flag by symbol category
        punct = [1 for symbol in token if (symbol in full_punctuation)]
        numerics = [1 for symbol in token if (symbol.isnumeric())]
        alpha = [1 for symbol in token if (symbol.isalpha())]

        # If token contains all types
        if (punct and numerics) and alpha:
            result['alpha_num_punct'].append(token)

        # Double
        elif numerics and punct:
            result['num_punct'].append(token)

        elif numerics and alpha:
            result['alpha_num'].append(token)

        elif alpha and punct:
            result['alpha_punct'].append(token)

        # Simple
        elif punct:
            result['punct_tokens'].append(token)

        elif numerics:
            result['numeric_tokens'].append(token)

        elif alpha:
            result['alpha_tokens'].append(token)
            
    return pd.DataFrame.from_dict(result, orient='index').transpose()

# %%
separated_df = separate_by_category(cu_by_freq_dataset)
separated_df.head()
# Out:
# 501626
#   num_punct alpha_num alpha_punct punct_tokens numeric_tokens alpha_tokens  \
# 0       3-4       мп3     еле-еле         None              2          год
# 1      8-10       мп3    какой-то         None              5     работать
# 2       5.1       ps3         т.е         None              2       устать
# 3        1.        3d     куда-то         None             50     лампочка
# 4        2.   xbox360    всё-таки         None             70       гореть
#
#   alpha_num_punct
# 0             2-х
# 1             4-х
# 2             4-х
# 3             3-х
# 4         sc-6570

# %%
def most_common_in_category(df):
    # 
    result = dict()
    for col in df.columns:
        try:
            col_most_freq = df[col].value_counts().reset_index()
            tokens = col_most_freq['index']
            freqs = col_most_freq[col]
            result[col] = [(t,f) for t,f in zip(tokens, freqs)]
        except:
            result[col] = [None]
    return pd.DataFrame.from_dict(result, orient='index').transpose()

most_common_in_category(separated_df)
# Out:
#         num_punct      alpha_num           alpha_punct punct_tokens  \
# 0       (2., 238)     (ps3, 102)            (т.к, 530)         None
# 1       (1., 224)      (mp3, 48)          (из-за, 440)         None
# 2       (3., 176)       (3d, 42)         (что-то, 311)         None
# 3       (4., 133)       (2х, 41)        (м-видео, 198)         None
# 4       (5., 116)       (3g, 31)            (т.е, 192)         None
# 5      (2-3, 112)       (м2, 23)        (м.видео, 163)         None
# 6       (3-4, 82)       (3х, 21)            (т.д, 121)         None
# 7       (1-2, 58)     (win7, 20)  (цена-качество, 120)         None
# 8       (1.5, 48)     (gta4, 20)            (p.s, 113)         None
# 9       (4-5, 37)     (ddr3, 20)         (как-то, 102)         None
# 10       (6., 37)      (мр3, 18)          (где-то, 95)         None
# 11       (7., 30)       (4х, 18)        (все-таки, 91)         None
# 12    (10-15, 29)      (4гб, 15)        (какой-то, 84)         None
# 13      (10., 25)      (8gb, 15)       (во-первых, 79)         None
# 14      (5-6, 22)    (2010г, 13)       (почему-то, 69)         None
# 15      (5-7, 20)      (8гб, 13)           (wi-fi, 60)         None
# 16      (2.5, 20)      (мп3, 13)             (т.п, 59)         None
# 17       (8., 19)       (5л, 12)              (г., 56)         None
# 18      (3-5, 19)      (sp3, 12)          (кто-то, 53)         None
# 19    (15-20, 18)       (е3, 12)        (какие-то, 51)         None
# 20      (6-7, 16)  (xbox360, 11)       (во-вторых, 51)         None
# 21     (16:9, 16)       (3й, 10)            (кв.м, 51)         None
# 22      (4:3, 15)      (4gb, 10)        (какое-то, 44)         None
# 23     (5-10, 14)       (i3, 10)        (по-моему, 42)         None
# 24      (2.0, 13)      (2гб, 10)      (что-нибудь, 41)         None
# 25    (30-40, 12)        (3д, 9)        (всё-таки, 40)         None
# 26    (20-30, 11)     (fat32, 9)         (blu-ray, 40)         None
# 27     (8-10, 11)     (2009г, 9)         (кому-то, 32)         None
# 28      (0.5, 11)     (1080р, 9)              (р., 31)         None
# 29      (7-8, 10)       (1gb, 9)             (т.р, 30)         None
# ...           ...            ...                   ...          ...
# 6429         None           None                  None         None
# 6430         None           None                  None         None
# 6431         None           None                  None         None
# 6432         None           None                  None         None
# 6433         None           None                  None         None
# 6434         None           None                  None         None
# 6435         None           None                  None         None
# 6436         None           None                  None         None
# 6437         None           None                  None         None
# 6438         None           None                  None         None
# 6439         None           None                  None         None
# 6440         None           None                  None         None
# 6441         None           None                  None         None
# 6442         None           None                  None         None
# 6443         None           None                  None         None
# 6444         None           None                  None         None
# 6445         None           None                  None         None
# 6446         None           None                  None         None
# 6447         None           None                  None         None
# 6448         None           None                  None         None
# 6449         None           None                  None         None
# 6450         None           None                  None         None
# 6451         None           None                  None         None
# 6452         None           None                  None         None
# 6453         None           None                  None         None
# 6454         None           None                  None         None
# 6455         None           None                  None         None
# 6456         None           None                  None         None
# 6457         None           None                  None         None
# 6458         None           None                  None         None
#
#      numeric_tokens           alpha_tokens alpha_num_punct
# 0         (2, 1910)            (не, 21912)       (2-х, 86)
# 1         (5, 1441)          (очень, 7658)       (3-х, 54)
# 2         (3, 1260)         (купить, 4751)       (2-й, 30)
# 3          (1, 960)        (хороший, 4228)       (4-х, 29)
# 4          (4, 843)            (год, 4157)       (3-й, 23)
# 5         (10, 464)       (работать, 3082)      (2-ой, 22)
# 6          (6, 341)   (пользоваться, 2597)      (5-ти, 11)
# 7          (7, 325)            (нет, 2509)       (1-й, 10)
# 8          (8, 269)       (отличный, 2447)       (1-го, 8)
# 9        (100, 255)         (просто, 2391)       (4-ку, 7)
# 10        (20, 210)      (довольный, 2320)        (4-й, 6)
# 11        (30, 186)        (большой, 2163)       (3-ей, 6)
# 12        (15, 184)            (раз, 2156)    (sc-6570, 6)
# 13        (50, 138)          (можно, 2050)            None
# 14        (12, 107)       (качество, 2014)            None
# 15         (9, 105)         (модель, 1930)            None
# 16         (32, 96)          (после, 1904)            None
# 17         (40, 90)           (цена, 1889)            None
# 18         (16, 82)           (даже, 1886)            None
# 19         (60, 81)          (время, 1790)            None
# 20          (0, 76)            (без, 1751)            None
# 21       (1000, 71)          (месяц, 1738)            None
# 22         (25, 70)          (через, 1731)            None
# 23         (11, 70)        (удобный, 1666)            None
# 24        (500, 68)         (хорошо, 1605)            None
# 25       (2010, 61)            (два, 1601)            None
# 26       (2009, 61)           (вода, 1569)            None
# 27        (200, 49)           (день, 1539)            None
# 28         (45, 48)           (звук, 1491)            None
# 29        (360, 45)          (минус, 1458)            None
# ...             ...                    ...             ...
# 6429           None    (индивидуальный, 6)            None
# 6430           None           (галочка, 6)            None
# 6431           None        (темноватый, 6)            None
# 6432           None            (объект, 6)            None
# 6433           None        (распознать, 6)            None
# 6434           None  (энергосбережение, 6)            None
# 6435           None         (телеканал, 6)            None
# 6436           None             (марля, 6)            None
# 6437           None             (метка, 6)            None
# 6438           None             (супра, 6)            None
# 6439           None               (атс, 6)            None
# 6440           None         (ослабнуть, 6)            None
# 6441           None       (сократиться, 6)            None
# 6442           None        (подвисания, 6)            None
# 6443           None          (молотить, 6)            None
# 6444           None          (заверить, 6)            None
# 6445           None     (передвигаться, 6)            None
# 6446           None         (прожарить, 6)            None
# 6447           None      (балансировка, 6)            None
# 6448           None    (восхитительный, 6)            None
# 6449           None          (алгоритм, 6)            None
# 6450           None       (мультимедия, 6)            None
# 6451           None        (промывание, 6)            None
# 6452           None        (программка, 6)            None
# 6453           None                (оф, 6)            None
# 6454           None       (насторожить, 6)            None
# 6455           None       (безотказный, 6)            None
# 6456           None         (нагружать, 6)            None
# 6457           None         (создатель, 6)            None
# 6458           None         (незаметно, 6)            None
#
# [6459 rows x 7 columns]

# %%
# Leave only alpha
alpha_tokens = set(separated_df['alpha_tokens'])

# %%
def cut_by_vocab(tokenlist):
    return [t for t in tokenlist if t in alpha_tokens]
only_alpha_dataset = apply_to_dataset(cu_by_freq_dataset, cut_by_vocab)
# Out:
# Symbols: 447200 30872 4234

# %%
freq_df_alpha = get_most_frequent_df(only_alpha_dataset)
freq_df_alpha.head()
# Out:
#    rank  occurance    token
# 0     0      21912       не
# 1     1       7658    очень
# 2     2       4751   купить
# 3     3       4228  хороший
# 4     4       4157      год

# %%
sns.lmplot(x='rank', y='occurance', data=freq_df_alpha.head(100), size=6)

# %% [markdown]
# # Check token lenght

# %%
len_tuples = [(each,len(each)) for each in alpha_tokens]
lets_see = sorted(len_tuples, reverse=True, key=lambda x: x[1])
lets_see[:10]
# Out:
# [('многофункциональность', 21),
#  ('проконсультироваться', 20),
#  ('многофункциональный', 19),
#  ('производительность', 18),
#  ('экспериментировать', 18),
#  ('воздухоувлажнитель', 18),
#  ('последовательность', 18),
#  ('стеклокерамический', 18),
#  ('самозатачивающийся', 18),
#  ('транспортировочный', 18)]

# %% [markdown]
# # POS-tags

# %%
def get_tokenchain(dataset):
    tokenlists = list(chain(*dataset)) # list(chain.from_iterable(all_columns))
    tokens = list(chain(*tokenlists))
    return tokens

# %%
alltokens_alpha = get_tokenchain(only_alpha_dataset)

# %%
tags_nltk_tuple = nltk.pos_tag(alltokens_alpha, lang='rus')
tags_nltk_tuple[:10]
# Out:
# [('год', 'S'),
#  ('работать', 'V'),
#  ('устать', 'V'),
#  ('лампочка', 'S'),
#  ('гореть', 'V'),
#  ('большой', 'A=m'),
#  ('ничто', 'S-PRO'),
#  ('через', 'PR'),
#  ('месяц', 'S'),
#  ('после', 'PR')]

# %%
tags = set([each[1] for each in tags_nltk_tuple])
len(tags)
# Out:
# 51

# %%
def get_tokens_by_tag(tag):
    # Set of tokens by input tag
    tagged_tokens = [each[0] for each in tags_nltk_tuple if each[1]==tag]
    return tagged_tokens

# {tag: [tokens]}
tag_dict = collections.OrderedDict(zip(tags, [get_tokens_by_tag(tag) for tag in tags]))

# %%
tag_frame = pd.DataFrame.from_dict(tag_dict, orient='index').transpose()

# %%
pd.options.display.max_columns = 51
most_common_in_df(tag_frame)
# Out:
#                      A       NUM=ins           NONLEX                   A=m  \
# 0           (рад, 106)  (драйвер, 1)       (usb, 186)       (хороший, 4187)
# 1           (рада, 84)          None        (hd, 171)      (отличный, 2363)
# 2           (браун, 4)          None      (hdmi, 156)     (довольный, 2301)
# 3          (деньга, 2)          None   (windows, 151)       (большой, 1692)
# 4           (худой, 2)          None      (sony, 151)       (удобный, 1526)
# 5               (х, 2)          None   (samsung, 143)     (нормальный, 989)
# 6          (дизайн, 2)          None        (lg, 132)          (общий, 867)
# 7           (плита, 1)          None       (dvd, 126)      (маленький, 792)
# 8           (нужно, 1)          None      (bork, 121)          (новый, 744)
# 9       (экземпляр, 1)          None   (philips, 105)   (единственный, 661)
# 10          (нокиа, 1)          None      (braun, 96)         (мощный, 617)
# 11    (электролюкс, 1)          None       (nbsp, 78)         (нужный, 603)
# 12           (ноль, 1)          None      (bosch, 68)        (главный, 513)
# 13          (носик, 1)          None      (nokia, 65)   (качественный, 489)
# 14        (горячее, 1)          None       (acer, 61)        (обычный, 476)
# 15           (ноут, 1)          None  (panasonic, 60)         (лёгкий, 446)
# 16      (некоторый, 1)          None       (quot, 57)     (компактный, 409)
# 17         (нагрев, 1)          None        (avi, 56)         (полный, 406)
# 18         (старое, 1)          None      (tefal, 53)  (замечательный, 400)
# 19      (эксклюзив, 1)          None        (hdd, 52)        (внешний, 398)
# 20            (бош, 1)          None        (psp, 52)       (красивый, 398)
# 21     (установщик, 1)          None        (mkv, 51)        (дорогой, 392)
# 22         (нетбук, 1)          None         (xp, 51)        (дешёвый, 379)
# 23    (консультант, 1)          None         (hp, 46)      (небольшой, 374)
# 24          (химия, 1)          None       (full, 41)         (плохой, 362)
# 25    (серебристый, 1)          None         (ps, 41)          (тихий, 356)
# 26         (филипс, 1)          None       (xbox, 41)        (высокий, 351)
# 27          (супра, 1)          None      (vista, 40)         (разный, 346)
# 28      (некоторые, 1)          None        (gps, 39)         (шумный, 339)
# 29           (итог, 1)          None    (indesit, 34)        (простой, 317)
# ...                ...           ...              ...                   ...
# 3160              None          None             None                  None
# 3161              None          None             None                  None
# 3162              None          None             None                  None
# 3163              None          None             None                  None
# 3164              None          None             None                  None
# 3165              None          None             None                  None
# 3166              None          None             None                  None
# 3167              None          None             None                  None
# 3168              None          None             None                  None
# 3169              None          None             None                  None
# 3170              None          None             None                  None
# 3171              None          None             None                  None
# 3172              None          None             None                  None
# 3173              None          None             None                  None
# 3174              None          None             None                  None
# 3175              None          None             None                  None
# 3176              None          None             None                  None
# 3177              None          None             None                  None
# 3178              None          None             None                  None
# 3179              None          None             None                  None
# 3180              None          None             None                  None
# 3181              None          None             None                  None
# 3182              None          None             None                  None
# 3183              None          None             None                  None
# 3184              None          None             None                  None
# 3185              None          None             None                  None
# 3186              None          None             None                  None
# 3187              None          None             None                  None
# 3188              None          None             None                  None
# 3189              None          None             None                  None
#
#                      CONJ        A-PRO=pl         A-PRO            ANUM=m  \
# 0               (ни, 773)    (многие, 88)   (таков, 12)       (один, 388)
# 1             (хотя, 669)        (др, 48)  (конечно, 4)   (шумноватый, 3)
# 2             (плюс, 541)  (некоторые, 8)   (короче, 3)  (дороговатый, 3)
# 3             (либо, 238)    (конечно, 2)       (тк, 1)   (слабоватый, 2)
# 4             (чтоб, 222)     (данные, 2)    (косяк, 1)         (семь, 1)
# 5           (причём, 207)        (мол, 1)   (таймер, 1)       (высота, 1)
# 6             (зато, 151)       (тупо, 1)          None        (супер, 1)
# 7           (однако, 121)            None          None         (тыща, 1)
# 8                (ли, 83)            None          None       (тефаля, 1)
# 9             (будто, 79)            None          None    (вытянутый, 1)
# 10        (поскольку, 75)            None          None       (чистый, 1)
# 11              (ибо, 60)            None          None       (частый, 1)
# 12             (пока, 44)            None          None         (чаща, 1)
# 13              (раз, 40)            None          None       (ноутом, 1)
# 14             (хоть, 30)            None          None       (штатив, 1)
# 15           (нежели, 13)            None          None  (шелковистый, 1)
# 16           (словно, 12)            None          None      (толстый, 1)
# 17            (притом, 6)            None          None              None
# 18              (ведь, 5)            None          None              None
# 19    (соответственно, 4)            None          None              None
# 20             (иначе, 4)            None          None              None
# 21             (благо, 3)            None          None              None
# 22            (молоть, 2)            None          None              None
# 23             (точно, 1)            None          None              None
# 24             (супер, 1)            None          None              None
# 25             (ковёр, 1)            None          None              None
# 26              (даже, 1)            None          None              None
# 27              (пыль, 1)            None          None              None
# 28              (хард, 1)            None          None              None
# 29             (минус, 1)            None          None              None
# ...                   ...             ...           ...               ...
# 3160                 None            None          None              None
# 3161                 None            None          None              None
# 3162                 None            None          None              None
# 3163                 None            None          None              None
# 3164                 None            None          None              None
# 3165                 None            None          None              None
# 3166                 None            None          None              None
# 3167                 None            None          None              None
# 3168                 None            None          None              None
# 3169                 None            None          None              None
# 3170                 None            None          None              None
# 3171                 None            None          None              None
# 3172                 None            None          None              None
# 3173                 None            None          None              None
# 3174                 None            None          None              None
# 3175                 None            None          None              None
# 3176                 None            None          None              None
# 3177                 None            None          None              None
# 3178                 None            None          None              None
# 3179                 None            None          None              None
# 3180                 None            None          None              None
# 3181                 None            None          None              None
# 3182                 None            None          None              None
# 3183                 None            None          None              None
# 3184                 None            None          None              None
# 3185                 None            None          None              None
# 3186                 None            None          None              None
# 3187                 None            None          None              None
# 3188                 None            None          None              None
# 3189                 None            None          None              None
#
#      ADV-PRO=comp               A=n           A-PRO=m                      V  \
# 0      (более, 1)      (целое, 181)     (самый, 1109)         (купить, 4751)
# 1            None      (новое, 158)    (другой, 1070)       (работать, 3082)
# 2            None   (основное, 141)     (данный, 716)   (пользоваться, 2597)
# 3            None      (лёгкое, 88)     (каждый, 702)       (покупать, 1416)
# 4            None       (равно, 84)       (один, 481)     (советовать, 1375)
# 5            None    (возможно, 77)      (какой, 416)          (брать, 1274)
# 6            None    (холодное, 64)  (некоторый, 267)  (рекомендовать, 1178)
# 7            None     (среднее, 61)        (сей, 236)         (сказать, 984)
# 8            None      (старое, 57)      (любой, 229)          (стоить, 982)
# 9            None       (нужно, 54)     (всякий, 156)           (стать, 980)
# 10           None      (удобно, 45)        (ваш, 148)     (понравиться, 957)
# 11           None      (похоже, 42)     (никакой, 54)          (думать, 851)
# 12           None       (малое, 30)   (недорогой, 39)       (нравиться, 803)
# 13           None      (видимо, 20)   (остальной, 38)         (сделать, 780)
# 14           None      (ночное, 18)        (иной, 13)          (хотеть, 762)
# 15           None     (понятно, 18)        (твой, 11)          (делать, 741)
# 16           None     (горячее, 16)       (некий, 10)           (взять, 698)
# 17           None   (настоящее, 14)          (наш, 8)    (использовать, 682)
# 18           None  (невозможно, 14)      (спасибо, 6)        (пожалеть, 659)
# 19           None    (наружное, 13)      (твёрдый, 5)         (хватать, 655)
# 20           None     (отлично, 11)          (том, 4)            (дать, 631)
# 21           None    (доступно, 11)      (конечно, 2)      (приобрести, 626)
# 22           None      (хорошо, 10)        (ковёр, 2)           (найти, 588)
# 23           None        (минус, 9)          (кой, 2)     (приходиться, 587)
# 24           None      (неплохо, 9)      (крутило, 1)            (идти, 585)
# 25           None      (частное, 9)         (каре, 1)           (знать, 569)
# 26           None       (просто, 9)        (норма, 1)       (сломаться, 568)
# 27           None      (главное, 7)  (необходимый, 1)        (прийтись, 561)
# 28           None      (прошлое, 7)       (крепёж, 1)        (выбирать, 555)
# 29           None      (заметно, 7)       (кривой, 1)      (получаться, 550)
# ...           ...               ...               ...                    ...
# 3160         None              None              None                   None
# 3161         None              None              None                   None
# 3162         None              None              None                   None
# 3163         None              None              None                   None
# 3164         None              None              None                   None
# 3165         None              None              None                   None
# 3166         None              None              None                   None
# 3167         None              None              None                   None
# 3168         None              None              None                   None
# 3169         None              None              None                   None
# 3170         None              None              None                   None
# 3171         None              None              None                   None
# 3172         None              None              None                   None
# 3173         None              None              None                   None
# 3174         None              None              None                   None
# 3175         None              None              None                   None
# 3176         None              None              None                   None
# 3177         None              None              None                   None
# 3178         None              None              None                   None
# 3179         None              None              None                   None
# 3180         None              None              None                   None
# 3181         None              None              None                   None
# 3182         None              None              None                   None
# 3183         None              None              None                   None
# 3184         None              None              None                   None
# 3185         None              None              None                   None
# 3186         None              None              None                   None
# 3187         None              None              None                   None
# 3188         None              None              None                   None
# 3189         None              None              None                   None
#
#                        ADV           NUM=m         A=plen      A-PRO=sg  \
# 0            (очень, 7658)     (два, 1579)  (очевидно, 1)  (всякий, 24)
# 1           (хорошо, 1520)  (полтора, 151)           None    (один, 15)
# 2            (назад, 1326)       (оба, 91)           None    (самый, 7)
# 3          (отлично, 1235)            None           None   (другой, 6)
# 4           (быстро, 1223)            None           None    (любой, 3)
# 5           (вообще, 1111)            None           None   (каждый, 3)
# 6             (пока, 1093)            None           None    (кухня, 2)
# 7             (долго, 956)            None           None  (твёрдый, 1)
# 8             (сразу, 914)            None           None     (сбой, 1)
# 9             (более, 857)            None           None   (таймер, 1)
# 10            (легко, 671)            None           None    (кулер, 1)
# 11           (сильно, 658)            None           None  (ноутбук, 1)
# 12            (почти, 654)            None           None     (твой, 1)
# 13       (достаточно, 620)            None           None     (трое, 1)
# 14          (немного, 581)            None           None          None
# 15           (вполне, 505)            None           None          None
# 16         (особенно, 481)            None           None          None
# 17    (действительно, 465)            None           None          None
# 18          (сегодня, 445)            None           None          None
# 19        (полностью, 441)            None           None          None
# 20        (постоянно, 437)            None           None          None
# 21           (совсем, 430)            None           None          None
# 22            (плохо, 403)            None           None          None
# 23         (довольно, 398)            None           None          None
# 24      (практически, 393)            None           None          None
# 25           (удобно, 372)            None           None          None
# 26            (также, 349)            None           None          None
# 27             (чуть, 335)            None           None          None
# 28           (иногда, 328)            None           None          None
# 29          (сначала, 319)            None           None          None
# ...                    ...             ...            ...           ...
# 3160                  None            None           None          None
# 3161                  None            None           None          None
# 3162                  None            None           None          None
# 3163                  None            None           None          None
# 3164                  None            None           None          None
# 3165                  None            None           None          None
# 3166                  None            None           None          None
# 3167                  None            None           None          None
# 3168                  None            None           None          None
# 3169                  None            None           None          None
# 3170                  None            None           None          None
# 3171                  None            None           None          None
# 3172                  None            None           None          None
# 3173                  None            None           None          None
# 3174                  None            None           None          None
# 3175                  None            None           None          None
# 3176                  None            None           None          None
# 3177                  None            None           None          None
# 3178                  None            None           None          None
# 3179                  None            None           None          None
# 3180                  None            None           None          None
# 3181                  None            None           None          None
# 3182                  None            None           None          None
# 3183                  None            None           None          None
# 3184                  None            None           None          None
# 3185                  None            None           None          None
# 3186                  None            None           None          None
# 3187                  None            None           None          None
# 3188                  None            None           None          None
# 3189                  None            None           None          None
#
#                   PART          NUM=nom         A=comp ADV-PRO=distort  \
# 0          (не, 21912)     (много, 348)  (короче, 121)       (щас, 19)
# 1       (просто, 2208)       (три, 172)     (выше, 80)            None
# 2         (даже, 1885)       (мало, 83)     (ниже, 56)            None
# 3         (тоже, 1139)     (четыре, 41)   (скорее, 21)            None
# 4            (ну, 676)    (сколько, 32)  (среднее, 12)            None
# 5       (конечно, 657)       (семь, 28)      (шире, 5)            None
# 6        (именно, 440)       (двое, 24)   (горячее, 4)            None
# 7            (ни, 370)       (пять, 22)      (тиша, 3)            None
# 8           (нет, 315)    (столько, 18)     (круча, 2)            None
# 9          (хоть, 274)  (несколько, 17)      (чаща, 2)            None
# 10           (ли, 208)       (трое, 17)    (точнее, 1)            None
# 11         (ведь, 158)      (шесть, 13)           None            None
# 12           (уж, 152)     (четверо, 6)           None            None
# 13         (лишь, 150)      (восемь, 4)           None            None
# 14         (хотя, 140)     (немного, 3)           None            None
# 15        (вроде, 107)      (десять, 1)           None            None
# 16          (таки, 74)      (мешать, 1)           None            None
# 17         (разве, 63)             None           None            None
# 18             (б, 54)             None           None            None
# 19    (пожалуйста, 53)             None           None            None
# 20            (аж, 52)             None           None            None
# 21         (прямо, 48)             None           None            None
# 22         (пусть, 46)             None           None            None
# 23             (ж, 23)             None           None            None
# 24         (якобы, 19)             None           None            None
# 25       (спасибо, 18)             None           None            None
# 26           (там, 15)             None           None            None
# 27         (точно, 14)             None           None            None
# 28           (фон, 13)             None           None            None
# 29           (мол, 11)             None           None            None
# ...                ...              ...            ...             ...
# 3160              None             None           None            None
# 3161              None             None           None            None
# 3162              None             None           None            None
# 3163              None             None           None            None
# 3164              None             None           None            None
# 3165              None             None           None            None
# 3166              None             None           None            None
# 3167              None             None           None            None
# 3168              None             None           None            None
# 3169              None             None           None            None
# 3170              None             None           None            None
# 3171              None             None           None            None
# 3172              None             None           None            None
# 3173              None             None           None            None
# 3174              None             None           None            None
# 3175              None             None           None            None
# 3176              None             None           None            None
# 3177              None             None           None            None
# 3178              None             None           None            None
# 3179              None             None           None            None
# 3180              None             None           None            None
# 3181              None             None           None            None
# 3182              None             None           None            None
# 3183              None             None           None            None
# 3184              None             None           None            None
# 3185              None             None           None            None
# 3186              None             None           None            None
# 3187              None             None           None            None
# 3188              None             None           None            None
# 3189              None             None           None            None
#
#            S-PRO=m            A-PRO=f           NUM=f   PRAEDIC-PRO  \
# 0     (таковой, 2)     (никакой, 847)     (деньга, 1)  (нечего, 57)
# 1             None      (другой, 283)  (остальной, 1)          None
# 2             None       (какой, 110)            None          None
# 3             None        (любой, 68)            None          None
# 4             None       (всякая, 20)            None          None
# 5             None      (таковой, 12)            None          None
# 6             None          (иной, 7)            None          None
# 7             None        (крутой, 4)            None          None
# 8             None         (тугой, 3)            None          None
# 9             None     (остальной, 3)            None          None
# 10            None         (кухня, 2)            None          None
# 11            None   (электролюкс, 2)            None          None
# 12            None         (супер, 2)            None          None
# 13            None          (ноут, 1)            None          None
# 14            None       (классно, 1)            None          None
# 15            None          (винд, 1)            None          None
# 16            None     (некоторый, 1)            None          None
# 17            None        (влитой, 1)            None          None
# 18            None        (кнопка, 1)            None          None
# 19            None       (касаемо, 1)            None          None
# 20            None          (каша, 1)            None          None
# 21            None      (максимум, 1)            None          None
# 22            None  (коротковатый, 1)            None          None
# 23            None     (сравнимый, 1)            None          None
# 24            None   (тяжеловатый, 1)            None          None
# 25            None     (недорогой, 1)            None          None
# 26            None          (сбой, 1)            None          None
# 27            None       (квадрат, 1)            None          None
# 28            None        (короче, 1)            None          None
# 29            None           (сей, 1)            None          None
# ...            ...                ...             ...           ...
# 3160          None               None            None          None
# 3161          None               None            None          None
# 3162          None               None            None          None
# 3163          None               None            None          None
# 3164          None               None            None          None
# 3165          None               None            None          None
# 3166          None               None            None          None
# 3167          None               None            None          None
# 3168          None               None            None          None
# 3169          None               None            None          None
# 3170          None               None            None          None
# 3171          None               None            None          None
# 3172          None               None            None          None
# 3173          None               None            None          None
# 3174          None               None            None          None
# 3175          None               None            None          None
# 3176          None               None            None          None
# 3177          None               None            None          None
# 3178          None               None            None          None
# 3179          None               None            None          None
# 3180          None               None            None          None
# 3181          None               None            None          None
# 3182          None               None            None          None
# 3183          None               None            None          None
# 3184          None               None            None          None
# 3185          None               None            None          None
# 3186          None               None            None          None
# 3187          None               None            None          None
# 3188          None               None            None          None
# 3189          None               None            None          None
#
#      INTJ=distort  PRAEDIC=comp          ADV-PRO        ANUM=f       S-PRO=f  \
# 0        (ааа, 1)  (среднее, 2)    (теперь, 762)   (прочее, 1)  (таковой, 1)
# 1            None  (твёрдый, 1)     (потом, 726)  (твёрдый, 1)          None
# 2            None          None       (там, 558)  (шустрый, 1)          None
# 3            None          None   (поэтому, 553)          None          None
# 4            None          None    (сейчас, 540)          None          None
# 5            None          None    (всегда, 489)          None          None
# 6            None          None       (тут, 399)          None          None
# 7            None          None       (где, 371)          None          None
# 8            None          None    (потому, 325)          None          None
# 9            None          None     (много, 223)          None          None
# 10           None          None     (тогда, 212)          None          None
# 11           None          None   (никогда, 182)          None          None
# 12           None          None     (здесь, 176)          None          None
# 13           None          None    (почему, 166)          None          None
# 14           None          None     (никак, 146)          None          None
# 15           None          None      (куда, 129)          None          None
# 16           None          None     (зачем, 117)          None          None
# 17           None          None     (иначе, 112)          None          None
# 18           None          None      (нигде, 85)          None          None
# 19           None          None       (туда, 82)          None          None
# 20           None          None      (везде, 78)          None          None
# 21           None          None     (никуда, 36)          None          None
# 22           None          None  (нисколько, 33)          None          None
# 23           None          None     (ничуть, 27)          None          None
# 24           None          None    (сколько, 23)          None          None
# 25           None          None     (откуда, 21)          None          None
# 26           None          None       (сюда, 19)          None          None
# 27           None          None      (столь, 17)          None          None
# 28           None          None    (столько, 16)          None          None
# 29           None          None     (посуда, 16)          None          None
# ...           ...           ...              ...           ...           ...
# 3160         None          None             None          None          None
# 3161         None          None             None          None          None
# 3162         None          None             None          None          None
# 3163         None          None             None          None          None
# 3164         None          None             None          None          None
# 3165         None          None             None          None          None
# 3166         None          None             None          None          None
# 3167         None          None             None          None          None
# 3168         None          None             None          None          None
# 3169         None          None             None          None          None
# 3170         None          None             None          None          None
# 3171         None          None             None          None          None
# 3172         None          None             None          None          None
# 3173         None          None             None          None          None
# 3174         None          None             None          None          None
# 3175         None          None             None          None          None
# 3176         None          None             None          None          None
# 3177         None          None             None          None          None
# 3178         None          None             None          None          None
# 3179         None          None             None          None          None
# 3180         None          None             None          None          None
# 3181         None          None             None          None          None
# 3182         None          None             None          None          None
# 3183         None          None             None          None          None
# 3184         None          None             None          None          None
# 3185         None          None             None          None          None
# 3186         None          None             None          None          None
# 3187         None          None             None          None          None
# 3188         None          None             None          None          None
# 3189         None          None             None          None          None
#
#                 PRAEDIC        NUM        INTJ                A=sg  \
# 0           (нет, 2190)  (пол, 58)   (ура, 52)      (простой, 102)
# 1         (можно, 2050)       None    (мм, 34)       (быстрый, 44)
# 2          (надо, 1051)       None   (увы, 25)       (хороший, 36)
# 3          (нужно, 807)       None  (стоп, 11)      (отличный, 29)
# 4         (удобно, 486)       None     (ой, 5)         (целое, 24)
# 5         (нельзя, 233)       None     (ах, 4)     (небольшой, 23)
# 6           (жаль, 191)       None  (супер, 1)      (приятный, 19)
# 7          (видно, 191)       None        None          (авто, 17)
# 8        (приятно, 165)       None        None     (некоторый, 16)
# 9        (спасибо, 128)       None        None     (довольный, 15)
# 10       (понятно, 123)       None        None     (маленькая, 15)
# 11    (невозможно, 123)       None        None        (старое, 13)
# 12          (нету, 101)       None        None       (большой, 12)
# 13          (легко, 84)       None        None     (маленький, 10)
# 14           (пора, 75)       None        None          (тихий, 9)
# 15         (хорошо, 75)       None        None        (сильный, 8)
# 16       (возможно, 62)       None        None       (активный, 8)
# 17         (трудно, 57)       None        None  (электрический, 7)
# 18       (неудобно, 53)       None        None        (рабочий, 7)
# 19         (сложно, 53)       None        None        (высокий, 7)
# 20           (мало, 42)       None        None         (лёгкий, 6)
# 21        (страшно, 40)       None        None        (болевой, 6)
# 22          (много, 35)       None        None         (слабый, 6)
# 23      (интересно, 33)       None        None       (звуковой, 6)
# 24         (тяжело, 31)       None        None          (худой, 6)
# 25        (странно, 24)       None        None     (прекрасный, 5)
# 26        (неплохо, 23)       None        None         (тёплый, 5)
# 27          (жалко, 22)       None        None         (мокрый, 5)
# 28      (непонятно, 18)       None        None        (пожилое, 5)
# 29      (неприятно, 18)       None        None         (нужный, 5)
# ...                 ...        ...         ...                 ...
# 3160               None       None        None                None
# 3161               None       None        None                None
# 3162               None       None        None                None
# 3163               None       None        None                None
# 3164               None       None        None                None
# 3165               None       None        None                None
# 3166               None       None        None                None
# 3167               None       None        None                None
# 3168               None       None        None                None
# 3169               None       None        None                None
# 3170               None       None        None                None
# 3171               None       None        None                None
# 3172               None       None        None                None
# 3173               None       None        None                None
# 3174               None       None        None                None
# 3175               None       None        None                None
# 3176               None       None        None                None
# 3177               None       None        None                None
# 3178               None       None        None                None
# 3179               None       None        None                None
# 3180               None       None        None                None
# 3181               None       None        None                None
# 3182               None       None        None                None
# 3183               None       None        None                None
# 3184               None       None        None                None
# 3185               None       None        None                None
# 3186               None       None        None                None
# 3187               None       None        None                None
# 3188               None       None        None                None
# 3189               None       None        None                None
#
#              ANUM=n           PARENTH               A=f                     S  \
# 0     (первое, 351)   (например, 204)    (большой, 457)           (год, 4157)
# 1      (второе, 64)     (впрочем, 43)  (остальной, 258)           (раз, 2115)
# 2      (третье, 24)      (конечно, 6)    (простой, 257)      (качество, 2014)
# 3       (прочее, 1)       (правда, 2)  (маленькая, 215)        (модель, 1930)
# 4         (друг, 1)     (наверное, 2)    (цифровой, 97)          (цена, 1889)
# 5      (видюхий, 1)       (значит, 1)       (сухой, 85)         (время, 1790)
# 6              None   (разумеется, 1)      (плохой, 81)         (месяц, 1738)
# 7              None          (мол, 1)       (ванна, 77)          (вода, 1569)
# 8              None       (видимо, 1)    (неплохой, 70)          (день, 1539)
# 9              None  (естественно, 1)      (прямая, 64)          (звук, 1491)
# 10             None              None   (небольшой, 64)      (проблема, 1453)
# 11             None              None    (основной, 51)         (минус, 1365)
# 12             None              None     (антенна, 48)          (игра, 1302)
# 13             None              None      (ручной, 48)       (покупка, 1265)
# 14             None              None     (игровой, 46)       (пылесос, 1251)
# 15             None              None       (сырой, 34)       (телефон, 1235)
# 16             None              None      (зубной, 32)        (работа, 1207)
# 17             None              None      (крутой, 30)        (чайник, 1195)
# 18             None              None         (кой, 30)       (машинка, 1182)
# 19             None              None     (сетевой, 29)        (деньга, 1158)
# 20             None              None      (родной, 28)          (режим, 941)
# 21             None              None      (минута, 27)         (кнопка, 916)
# 22             None              None   (недорогой, 25)  (использование, 913)
# 23             None              None       (низка, 24)         (дизайн, 901)
# 24             None              None      (кривая, 23)        (наушник, 894)
# 25             None              None      (ванная, 22)          (волос, 878)
# 26             None              None     (бытовой, 22)        (функция, 871)
# 27             None              None    (звуковой, 21)         (неделя, 863)
# 28             None              None   (выдвижной, 21)         (фильтр, 839)
# 29             None              None     (часовой, 20)        (магазин, 830)
# ...             ...               ...               ...                   ...
# 3160           None              None              None          (сначало, 1)
# 3161           None              None              None            (сжечь, 1)
# 3162           None              None              None           (колено, 1)
# 3163           None              None              None            (hansa, 1)
# 3164           None              None              None        (шерстяной, 1)
# 3165           None              None              None          (чумовой, 1)
# 3166           None              None              None    (комплектовать, 1)
# 3167           None              None              None              (led, 1)
# 3168           None              None              None             (kicx, 1)
# 3169           None              None              None         (входящая, 1)
# 3170           None              None              None            (какой, 1)
# 3171           None              None              None             (сухо, 1)
# 3172           None              None              None          (тройной, 1)
# 3173           None              None              None          (чистить, 1)
# 3174           None              None              None           (шипеть, 1)
# 3175           None              None              None        (зависнуть, 1)
# 3176           None              None              None            (сбоку, 1)
# 3177           None              None              None          (сердито, 1)
# 3178           None              None              None        (одиночный, 1)
# 3179           None              None              None               (ps, 1)
# 3180           None              None              None           (неттоп, 1)
# 3181           None              None              None          (горелый, 1)
# 3182           None              None              None          (прошлый, 1)
# 3183           None              None              None            (инуть, 1)
# 3184           None              None              None              (max, 1)
# 3185           None              None              None          (вонючий, 1)
# 3186           None              None              None            (долив, 1)
# 3187           None              None              None               (уж, 1)
# 3188           None              None              None            (полый, 1)
# 3189           None              None              None        (устарелый, 1)
#
#              A=brev           NUM=acc      ADV=comp                  PR  \
# 0        (нужно, 1)        (три, 473)  (скорее, 91)       (после, 1904)
# 1        (ванна, 1)  (несколько, 442)  (точнее, 62)         (без, 1751)
# 2     (возможно, 1)      (много, 378)   (менее, 24)       (через, 1731)
# 3              None    (сколько, 174)  (короче, 14)            (с, 809)
# 4              None       (пять, 118)     (выше, 9)          (под, 735)
# 5              None     (столько, 92)  (среднее, 2)        (около, 463)
# 6              None      (четыре, 85)     (ниже, 2)          (про, 357)
# 7              None         (сто, 51)          None        (перед, 274)
# 8              None        (семь, 37)          None        (кроме, 216)
# 9              None        (мало, 37)          None        (между, 206)
# 10             None      (десять, 24)          None       (внутри, 186)
# 11             None       (чаять, 16)          None        (вроде, 181)
# 12             None         (два, 12)          None       (спустя, 127)
# 13             None       (восемь, 7)          None       (вместо, 124)
# 14             None        (шесть, 7)          None    (благодаря, 111)
# 15             None      (немного, 5)          None        (насчёт, 86)
# 16             None       (нажать, 4)          None           (над, 85)
# 17             None       (немало, 4)          None        (вокруг, 59)
# 18             None    (частенько, 2)          None        (прежде, 56)
# 19             None     (нажимать, 2)          None         (среди, 46)
# 20             None         (пара, 2)          None  (относительно, 36)
# 21             None         (ноут, 2)          None        (против, 35)
# 22             None        (тесто, 2)          None          (ради, 34)
# 23             None      (стирать, 2)          None         (возле, 33)
# 24             None       (дизайн, 2)          None          (мимо, 29)
# 25             None      (хватать, 2)          None       (включая, 28)
# 26             None         (трое, 2)          None        (помимо, 25)
# 27             None       (ноготь, 1)          None         (ввиду, 24)
# 28             None         (село, 1)          None         (путём, 24)
# 29             None     (наливать, 1)          None           (вне, 22)
# ...             ...               ...           ...                 ...
# 3160           None              None          None                None
# 3161           None              None          None                None
# 3162           None              None          None                None
# 3163           None              None          None                None
# 3164           None              None          None                None
# 3165           None              None          None                None
# 3166           None              None          None                None
# 3167           None              None          None                None
# 3168           None              None          None                None
# 3169           None              None          None                None
# 3170           None              None          None                None
# 3171           None              None          None                None
# 3172           None              None          None                None
# 3173           None              None          None                None
# 3174           None              None          None                None
# 3175           None              None          None                None
# 3176           None              None          None                None
# 3177           None              None          None                None
# 3178           None              None          None                None
# 3179           None              None          None                None
# 3180           None              None          None                None
# 3181           None              None          None                None
# 3182           None              None          None                None
# 3183           None              None          None                None
# 3184           None              None          None                None
# 3185           None              None          None                None
# 3186           None              None          None                None
# 3187           None              None          None                None
# 3188           None              None          None                None
# 3189           None              None          None                None
#
#             ANUM=sg               A=pl NONLEX=abbr       NUM=gen    NUM=comp  \
# 0         (один, 2)       (родные, 38)   (rain, 1)  (триммер, 1)  (более, 3)
# 1       (первое, 2)         (жмых, 35)        None     (друг, 1)        None
# 2         (обед, 1)        (белые, 25)        None       (дб, 1)        None
# 3     (сетчатый, 1)           (кв, 23)        None          None        None
# 4      (пылесос, 1)         (след, 14)        None          None        None
# 5         (течь, 1)    (нарекание, 11)        None          None        None
# 6     (панелька, 1)         (белых, 8)        None          None        None
# 7         (пара, 1)     (кипячение, 2)        None          None        None
# 8       (тормоз, 1)  (переключение, 2)        None          None        None
# 9              None     (крепление, 2)        None          None        None
# 10             None   (изображение, 2)        None          None        None
# 11             None         (минус, 2)        None          None        None
# 12             None     (включение, 2)        None          None        None
# 13             None        (кстати, 2)        None          None        None
# 14             None         (отдых, 2)        None          None        None
# 15             None      (терпение, 2)        None          None        None
# 16             None        (деньга, 2)        None          None        None
# 17             None     (наливание, 2)        None          None        None
# 18             None         (экран, 2)        None          None        None
# 19             None         (супер, 1)        None          None        None
# 20             None    (скольжение, 1)        None          None        None
# 21             None            (тв, 1)        None          None        None
# 22             None   (раздражение, 1)        None          None        None
# 23             None         (нокиа, 1)        None          None        None
# 24             None      (сомнение, 1)        None          None        None
# 25             None     (напыление, 1)        None          None        None
# 26             None        (дизайн, 1)        None          None        None
# 27             None          (дача, 1)        None          None        None
# 28             None           (юсб, 1)        None          None        None
# 29             None      (звучание, 1)        None          None        None
# ...             ...                ...         ...           ...         ...
# 3160           None               None        None          None        None
# 3161           None               None        None          None        None
# 3162           None               None        None          None        None
# 3163           None               None        None          None        None
# 3164           None               None        None          None        None
# 3165           None               None        None          None        None
# 3166           None               None        None          None        None
# 3167           None               None        None          None        None
# 3168           None               None        None          None        None
# 3169           None               None        None          None        None
# 3170           None               None        None          None        None
# 3171           None               None        None          None        None
# 3172           None               None        None          None        None
# 3173           None               None        None          None        None
# 3174           None               None        None          None        None
# 3175           None               None        None          None        None
# 3176           None               None        None          None        None
# 3177           None               None        None          None        None
# 3178           None               None        None          None        None
# 3179           None               None        None          None        None
# 3180           None               None        None          None        None
# 3181           None               None        None          None        None
# 3182           None               None        None          None        None
# 3183           None               None        None          None        None
# 3184           None               None        None          None        None
# 3185           None               None        None          None        None
# 3186           None               None        None          None        None
# 3187           None               None        None          None        None
# 3188           None               None        None          None        None
# 3189           None               None        None          None        None
#
#              A-PRO=n    ADV=comp2             S-PRO      NUM=n  \
# 0        (кнопка, 5)  (похоже, 2)      (ничто, 948)  (два, 10)
# 1        (таймер, 4)    (пара, 1)       (друг, 202)   (доп, 1)
# 2        (деньга, 2)         None      (никто, 186)       None
# 3            (тв, 2)         None      (прочее, 28)       None
# 4          (толь, 2)         None      (многие, 26)       None
# 5         (кухня, 2)         None       (нечто, 17)       None
# 6         (минус, 2)         None      (многое, 11)       None
# 7         (видно, 2)         None         (чаща, 5)       None
# 8          (ноут, 1)         None           (че, 4)       None
# 9         (кодек, 1)         None       (всякий, 4)       None
# 10         (итак, 1)         None        (чехол, 3)       None
# 11        (нокия, 1)         None        (любой, 2)       None
# 12      (инженер, 1)         None        (чаять, 2)       None
# 13         (дача, 1)         None        (кухня, 2)       None
# 14    (некоторый, 1)         None     (термопот, 1)       None
# 15       (особый, 1)         None       (тряпка, 1)       None
# 16      (ноутбук, 1)         None           (жк, 1)       None
# 17       (высота, 1)         None       (привет, 1)       None
# 18      (игровой, 1)         None     (кастрюля, 1)       None
# 19       (кстати, 1)         None    (некоторый, 1)       None
# 20       (ноготь, 1)         None        (скайп, 1)       None
# 21      (начинка, 1)         None      (покупка, 1)       None
# 22          (дно, 1)         None       (видимо, 1)       None
# 23    (недорогой, 1)         None       (чёткий, 1)       None
# 24       (эконом, 1)         None  (мультиварка, 1)       None
# 25      (спереди, 1)         None           (др, 1)       None
# 26       (короче, 1)         None      (спасибо, 1)       None
# 27      (вытяжка, 1)         None           (чё, 1)       None
# 28      (напрячь, 1)         None    (uncharted, 1)       None
# 29       (диалог, 1)         None     (недорого, 1)       None
# ...              ...          ...               ...        ...
# 3160            None         None              None       None
# 3161            None         None              None       None
# 3162            None         None              None       None
# 3163            None         None              None       None
# 3164            None         None              None       None
# 3165            None         None              None       None
# 3166            None         None              None       None
# 3167            None         None              None       None
# 3168            None         None              None       None
# 3169            None         None              None       None
# 3170            None         None              None       None
# 3171            None         None              None       None
# 3172            None         None              None       None
# 3173            None         None              None       None
# 3174            None         None              None       None
# 3175            None         None              None       None
# 3176            None         None              None       None
# 3177            None         None              None       None
# 3178            None         None              None       None
# 3179            None         None              None       None
# 3180            None         None              None       None
# 3181            None         None              None       None
# 3182            None         None              None       None
# 3183            None         None              None       None
# 3184            None         None              None       None
# 3185            None         None              None       None
# 3186            None         None              None       None
# 3187            None         None              None       None
# 3188            None         None              None       None
# 3189            None         None              None       None
#
#               A=comp2
# 0         (похоже, 4)
# 1          (помол, 1)
# 2     (перемолоть, 1)
# 3             (пр, 1)
# 4          (проба, 1)
# 5                None
# 6                None
# 7                None
# 8                None
# 9                None
# 10               None
# 11               None
# 12               None
# 13               None
# 14               None
# 15               None
# 16               None
# 17               None
# 18               None
# 19               None
# 20               None
# 21               None
# 22               None
# 23               None
# 24               None
# 25               None
# 26               None
# 27               None
# 28               None
# 29               None
# ...               ...
# 3160             None
# 3161             None
# 3162             None
# 3163             None
# 3164             None
# 3165             None
# 3166             None
# 3167             None
# 3168             None
# 3169             None
# 3170             None
# 3171             None
# 3172             None
# 3173             None
# 3174             None
# 3175             None
# 3176             None
# 3177             None
# 3178             None
# 3179             None
# 3180             None
# 3181             None
# 3182             None
# 3183             None
# 3184             None
# 3185             None
# 3186             None
# 3187             None
# 3188             None
# 3189             None
#
# [3190 rows x 51 columns]

# %%
tag_frame.count().plot.barh(fontsize=15, figsize=(11, 11))

# %%
good_tags = ['A', 'A=m', 'ADV', 'V', 'PART', 'A=comp', 'A-PRO=f', 'PRAEDIC', 'INTJ', 'A=sg', 'A=f', 'S', 'ADV=comp', 'S-PR']
good_vocab = list(set(chain.from_iterable([get_tokens_by_tag(tag) for tag in good_tags])))
good_vocab[:5]
# Out:
# ['переезжать', 'обменивать', 'наверно', 'скребок', 'строго']

# %%
def cut_by_good_vocab(tokenlist):
    return [t for t in tokenlist if t in good_vocab]
pos_cleaned_dataset = apply_to_dataset(only_alpha_dataset, cut_by_good_vocab)
# Out:
# Symbols: 423955 29202 4039

# %%
dataset_df = pd.concat([df['reting'], pos_cleaned_dataset[0], pos_cleaned_dataset[1], pos_cleaned_dataset[2]], axis=1)
dataset_df.head()
# Out:
#    reting                                            comment commentPositive  \
# 0     2.0  [год, работать, устать, лампочка, гореть, боль...             NaN
# 1     2.0  [месяц, истечение, гарантийный, срок, машинка,...             NaN
# 2     4.0  [пользоваться, неделя, нарекание, ни, какой, н...             NaN
# 3     5.0  [ребята, системный, блок, подойти, игра, го, с...             NaN
# 4     5.0  [считать, замечательный, телефон, приятно, дер...             NaN
#
#   commentNegative
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
len(dataset_df)
# Out:
# 15587

# %%
def check_empty_texts(series):
    """Get unprocessed text for '[]' in Series"""
    empty_texts_indexes = series[series.astype(str) == '[]'].index
    return empty_texts_indexes
def remove_empty_texts(df):
    empty_indexes = check_empty_texts(dataset_df['comment'])
    df = df.drop(empty_indexes)
    return df

# %%
final_dataset = remove_empty_texts(dataset_df)
print(len(dataset_df), len(final_dataset))
final_dataset.head()
# Out:
# 15587 15553
#    reting                                            comment commentPositive  \
# 0     2.0  [год, работать, устать, лампочка, гореть, боль...             NaN
# 1     2.0  [месяц, истечение, гарантийный, срок, машинка,...             NaN
# 2     4.0  [пользоваться, неделя, нарекание, ни, какой, н...             NaN
# 3     5.0  [ребята, системный, блок, подойти, игра, го, с...             NaN
# 4     5.0  [считать, замечательный, телефон, приятно, дер...             NaN
#
#   commentNegative
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
def join_tokens(tokenlist):
    try:
        return ' '.join(tokenlist)
    except TypeError:
        return np.nan

# %%
final_dataset['comment_joined'] = [join_tokens(tokenlist) for tokenlist in final_dataset['comment']]
final_dataset['commentPositive_joined'] = [join_tokens(tokenlist)  for tokenlist in final_dataset['commentPositive'] ]
final_dataset['commentNegative_joined'] = [join_tokens(tokenlist)  for tokenlist in final_dataset['commentNegative']]
final_dataset.head()
# Out:
#    reting                                            comment commentPositive  \
# 0       2  [год, работать, устать, лампочка, гореть, боль...             NaN
# 1       2  [месяц, истечение, гарантийный, срок, машинка,...             NaN
# 2       4  [пользоваться, неделя, нарекание, ни, какой, н...             NaN
# 3       5  [ребята, системный, блок, подойти, игра, го, с...             NaN
# 4       5  [считать, замечательный, телефон, приятно, дер...             NaN
#
#   commentNegative                                     comment_joined  \
# 0             NaN        год работать устать лампочка гореть большой
# 1             NaN  месяц истечение гарантийный срок машинка навер...
# 2             NaN  пользоваться неделя нарекание ни какой не поло...
# 3             NaN      ребята системный блок подойти игра го средний
# 4             NaN  считать замечательный телефон приятно держать ...
#
#   commentPositive_joined                                       BoW-unigrams  \
# 0                    NaN    (0, 323)\t1\n  (0, 965)\t1\n  (0, 2191)\t1\n...
# 1                    NaN    (0, 323)\t1\n  (0, 965)\t1\n  (0, 2191)\t1\n...
# 2                    NaN    (0, 323)\t1\n  (0, 965)\t1\n  (0, 2191)\t1\n...
# 3                    NaN    (0, 323)\t1\n  (0, 965)\t1\n  (0, 2191)\t1\n...
# 4                    NaN    (0, 323)\t1\n  (0, 965)\t1\n  (0, 2191)\t1\n...
#
#                                           BoW-uni+bi commentNegative_joined
# 0    (0, 35286)\t1\n  (0, 84097)\t1\n  (0, 227357...                    NaN
# 1    (0, 35286)\t1\n  (0, 84097)\t1\n  (0, 227357...                    NaN
# 2    (0, 35286)\t1\n  (0, 84097)\t1\n  (0, 227357...                    NaN
# 3    (0, 35286)\t1\n  (0, 84097)\t1\n  (0, 227357...                    NaN
# 4    (0, 35286)\t1\n  (0, 84097)\t1\n  (0, 227357...                    NaN

# %%
vectorizer_u  = CountVectorizer(ngram_range=(1, 1))
# vectorizer_b  = CountVectorizer(ngram_range=(2, 2))
vectorizer_ub = CountVectorizer(ngram_range=(1, 2))

# %%
# Dataset
final_dataset['BoW-unigrams'] =  vectorizer_u.fit_transform(final_dataset['comment_joined'])
# counts_b  = vectorizer_b.fit_transform(refined_df['comment'])
final_dataset['BoW-uni+bi'] = vectorizer_ub.fit_transform(final_dataset['comment_joined'])
final_dataset.head(3)
# Out:
#    reting                                            comment commentPositive  \
# 0       2  [год, работать, устать, лампочка, гореть, боль...             NaN
# 1       2  [месяц, истечение, гарантийный, срок, машинка,...             NaN
# 2       4  [пользоваться, неделя, нарекание, ни, какой, н...             NaN
#
#   commentNegative                                     comment_joined  \
# 0             NaN        год работать устать лампочка гореть большой
# 1             NaN  месяц истечение гарантийный срок машинка навер...
# 2             NaN  пользоваться неделя нарекание ни какой не поло...
#
#   commentPositive_joined                                       BoW-unigrams  \
# 0                    NaN    (0, 323)\t1\n  (0, 965)\t1\n  (0, 2191)\t1\n...
# 1                    NaN    (0, 323)\t1\n  (0, 965)\t1\n  (0, 2191)\t1\n...
# 2                    NaN    (0, 323)\t1\n  (0, 965)\t1\n  (0, 2191)\t1\n...
#
#                                           BoW-uni+bi commentNegative_joined
# 0    (0, 35286)\t1\n  (0, 84097)\t1\n  (0, 227357...                    NaN
# 1    (0, 35286)\t1\n  (0, 84097)\t1\n  (0, 227357...                    NaN
# 2    (0, 35286)\t1\n  (0, 84097)\t1\n  (0, 227357...                    NaN

# %% [markdown]
# # Model training

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %% [markdown]
# # 1st layer model (binary 5/not5 prediction)

# %%
final_dataset['binary_reting'] = final_dataset['reting'].apply(lambda x: 0 if x==5 else 1)
# cut_df['reting'] = final_dataset['reting'].apply(round)
# cut_df = cut_df[cut_df.reting != 5]

# %%
cut_counts_ub = vectorizer_ub.transform(cut_df['comment_joined'])

# %%
rf_gini = RandomForestClassifier(n_estimators = 500, max_depth=50,class_weight='balanced', n_jobs=4, criterion='gini')

# %%
rf_gini.fit(cut_counts_ub, final_dataset['binary_reting'])
# Out:
# RandomForestClassifier(bootstrap=True, class_weight='balanced',
#             criterion='gini', max_depth=50, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=500, n_jobs=4, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
rf_gini.predict(cut_counts_ub)[:5]
# Out:
# array([1, 1, 1, 0, 0], dtype=int64)

# %% [markdown]
# # 2nd layer

# %%
cut_df = final_dataset[final_dataset.reting != 5]
cut_df['reting'].hist()

# %%
four_class_counts_ub = vectorizer_ub.transform(cut_df['comment_joined'])
cut_rf_gini_ub = RandomForestClassifier(n_estimators = 500,
                                              max_depth=50,
                                              class_weight='balanced',
                                              n_jobs=4,
                                              criterion='gini')

# %%
cut_rf_gini_ub.fit(four_class_counts_ub, cut_df['reting'])
# Out:
# RandomForestClassifier(bootstrap=True, class_weight='balanced',
#             criterion='gini', max_depth=50, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=500, n_jobs=4, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
cut_rf_gini_ub.predict(four_class_counts_ub)[:5]
# Out:
# array([1, 2, 4, 1, 2], dtype=int64)

# %%
def preprocessing_line(comment_string):
    normalized = comment_string.lower().strip().replace('\n', ' ').replace('\r', ' ').replace('\t', ' ')
    padded =  pp.pad_punctuation(normalized)
    tokenized = nltk.word_tokenize(padded) # counting tokens now
    no_punct = pp.remove_punct(tokenized)
    no_stopwords = pp.remove_stopwords(no_punct)
    # print(no_stopwords)
    cut_by_vocab = [t for t in no_stopwords if t in alpha_tokens]
    return cut_by_vocab

# %%
preprocessing_line('привет как дела все очень хорошо')
# Out:
# ['привет', 'очень', 'хорошо']

# %%
def predict(commentary):
    preprocessed = preprocessing_line(commentary)
    comment_string = join_tokens(preprocessed)
    # print(comment_string)
    bow = vectorizer_ub.transform([comment_string,])
    binary_prediction = rf_gini.predict(bow)
    if binary_prediction == 0:
        return 5
    else:
        return cut_rf_gini_ub.predict(bow)

# %%
predict('привет как дела все очень хорошо')
# Out:
# 5

# %%
predictions = df['comment'].sample(10).map(predict)
predictions
# Out:
# 9877       5
# 10072    [1]
# 307      [1]
# 3798     [1]
# 8654       5
# 4610     [1]
# 11462      5
# 3038       5
# 2115       5
# 3279       5
# Name: comment, dtype: object

# %%
kfold = KFold(n_splits=3, shuffle=True, random_state=0)
results = []
for n_estimators in [10, 50, 100, 200, 500]:
    for max_depth in [5, 10, 20, 50]:
        cut_rf_gini_ub = RandomForestClassifier(n_estimators = n_estimators,
                                              max_depth=max_depth,
                                              class_weight='balanced',
                                              n_jobs=4,
                                              criterion='gini')
        
        cv_u  = cross_val_score(predictor,  cut_counts_ub,  final_dataset['reting'], cv=kfold)
        print("cross validation svm+unigrams:\n{}\nn_estimators:{}\nmax_depth:{}\n".format(cv_u,
                                                                                           n_estimators,
                                                                                           max_depth))
        results.append(np.mean(cv_u))
# Out:
# cross validation svm+unigrams:
# [ 0.21947927  0.28260031  0.29436728]
# n_estimators:10
# max_depth:5
#
# cross validation svm+unigrams:
# [ 0.24088717  0.3435571   0.28761574]
# n_estimators:10
# max_depth:10
#
# cross validation svm+unigrams:
# [ 0.41620058  0.36130401  0.51890432]
# n_estimators:10
# max_depth:20
#
# cross validation svm+unigrams:
# [ 0.48216008  0.47202932  0.54552469]
# n_estimators:10
# max_depth:50
#
# cross validation svm+unigrams:
# [ 0.40578592  0.39390432  0.38097994]
# n_estimators:50
# max_depth:5
#
# cross validation svm+unigrams:
# [ 0.50298939  0.49594907  0.46739969]
# n_estimators:50
# max_depth:10
#
# cross validation svm+unigrams:
# [ 0.55621986  0.56462191  0.55497685]
# n_estimators:50
# max_depth:20
#
# cross validation svm+unigrams:
# [ 0.61099325  0.61072531  0.63271605]
# n_estimators:50
# max_depth:50
#
# cross validation svm+unigrams:
# [ 0.49681774  0.47588735  0.47588735]
# n_estimators:100
# max_depth:5
#
# cross validation svm+unigrams:
# [ 0.55564127  0.5476466   0.54513889]
# n_estimators:100
# max_depth:10
#
# cross validation svm+unigrams:
# [ 0.5828351   0.57908951  0.58179012]
# n_estimators:100
# max_depth:20
#
# cross validation svm+unigrams:
# [ 0.61002893  0.62210648  0.62191358]
# n_estimators:100
# max_depth:50
#
# cross validation svm+unigrams:
# [ 0.50819672  0.54070216  0.52276235]
# n_estimators:200
# max_depth:5
#
# cross validation svm+unigrams:
# [ 0.55371263  0.57716049  0.58449074]
# n_estimators:200
# max_depth:10
#
# cross validation svm+unigrams:
# [ 0.58823529  0.59606481  0.59972994]
# n_estimators:200
# max_depth:20
#
# cross validation svm+unigrams:
# [ 0.62603664  0.62827932  0.62731481]
# n_estimators:200
# max_depth:50
#
# cross validation svm+unigrams:
# [ 0.55699132  0.56500772  0.5462963 ]
# n_estimators:500
# max_depth:5
#
# cross validation svm+unigrams:
# [ 0.57261331  0.5943287   0.59066358]
# n_estimators:500
# max_depth:10
#
# cross validation svm+unigrams:
# [ 0.59556413  0.61111111  0.61959877]
# n_estimators:500
# max_depth:20
#
# cross validation svm+unigrams:
# [ 0.62661524  0.64178241  0.63657407]
# n_estimators:500
# max_depth:50

# %%
results
# Out:
# [0.26548228656975842,
#  0.29068667134937359,
#  0.43213630397514197,
#  0.49990469649709707,
#  0.39355672672833553,
#  0.48877938597013387,
#  0.55860621014242573,
#  0.61814486926120382,
#  0.48286414494962121,
#  0.54947558890992132,
#  0.58123824362774867,
#  0.61801633044434123,
#  0.5238870758281049,
#  0.57178795572064078,
#  0.59467668240135563,
#  0.62721025998944402,
#  0.55609844448809687,
#  0.58586853052291554,
#  0.60875800127782342,
#  0.63499057257997304]

# %%
def heatmap(values, xlabel, ylabel, xticklabels, yticklabels, cmap=None,
            vmin=None, vmax=None, ax=None, fmt="%0.2f"):
    if ax is None:
        ax = plt.gca()
    # plot the mean cross-validation scores
    img = ax.pcolor(values, cmap=cmap, vmin=vmin, vmax=vmax)
    img.update_scalarmappable()
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_xticks(np.arange(len(xticklabels)) + .5)
    ax.set_yticks(np.arange(len(yticklabels)) + .5)
    ax.set_xticklabels(xticklabels)
    ax.set_yticklabels(yticklabels)
    ax.set_aspect(1)

    for p, color, value in zip(img.get_paths(), img.get_facecolors(),
                               img.get_array()):
        x, y = p.vertices[:-2, :].mean(0)
        if np.mean(color[:3]) > 0.5:
            c = 'k'
        else:
            c = 'w'
        ax.text(x, y, fmt % value, color=c, ha="center", va="center")
    return img

# %%
scores = np.array(results).reshape(5, 4)
param_grid = {'n_estimators': [10, 50, 100, 200, 500],
              'max_depth': [5, 10, 20, 50]}
heatmap(scores, ylabel='n_estimators', yticklabels=param_grid['n_estimators'],
xlabel='max_depth', xticklabels=param_grid['max_depth'], cmap="viridis")

# %%
cv_ub = cross_val_score(cut_rf_gini_ub, cut_counts_ub, cut_df['reting'], cv=kfold)
